# %% [markdown]
# # Lab 04: Object-Oriented Programming (OOP)

# %% [markdown]
# ## Student's Information Management
#
# **Requirement:** Write a program that manage student's information, include **Student** class and **School** class.

# %% [markdown]
# #### Student Class:
# * **Attribute:**
#
#     * `name` (student name)
#
#     * `age` (student age)
#
#     * `grades` - list of student grades.
#
# * **Methods:**
#
#     * *Getter* và *Setter* for `name` and `age`. (private)
#
#     * *add_grade(grade)* - Add grade into list of grades.
#
#     * *calculate_average()* - Calculate and return student's average grade.
#
#     * *describe()* - Describe student's information (name, age, average grade).

# %%
class Student:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age
        self.grades = []

    @property
    def name(self):
        return self.__name

    @name.setter
    def name(self, name):
        if not isinstance(name, str):
            raise ValueError("Name must be a string.")
        self.__name = name

    @property
    def age(self):
        return self.__age

    @age.setter
    def age(self, age):
        if age <= 0:
            raise ValueError("Age must be a positive number.")
        self.__age = age
    
    def add_grade(self, grade):
        if grade < 0:
            raise ValueError("Grade must be a positive number.")
        self.grades.append(grade)
        print(f"Added grade {grade} to {self.name}'s grade list.")
        
    def calculate_average(self):
        if self.grades:
            return sum(self.grades) / len(self.grades)
        return 0
        
    def describe(self):
        print(f"Name: {self.name}\nAge: {self.age}\nGrade: {self.grades}\nAverage Grade: {self.calculate_average()}\n")

# %% [markdown]
# #### School Class:
#
# * **Attribute:**
#
#     * `students` (list of Student object).
#
# * **Methods:**
#
#     * *add_student(student)* - Add new student into list.
#
#     * *remove_student(name)* - Remove student from list.
#
#     * *find_student(name)* - Find student by name and return information if have.
#
#     * *get_top_student()* - Return student with the highest average grade of school.

# %%
class School:
    def __init__(self):
        self.students = []

    def add_student(self, student):
        self.students.append(student)
        print(f"Added {student.name} to the student list.")
        
    def remove_student(self, name):
        for student in self.students:
            if student.name == name:
                self.students.remove(student)
                print(f"Removed {student.name} from the student list.")
                return
        print(f"{name} not found in the student list!")
              
    def find_student(self, name):
        for student in self.students:
            if student.name == name:
                return student.describe()
        print(f"{name} not found in the student list!")

    def get_top_student(self):
        top_students = [] # students list with the highest average grade
        top_grade = max(student.calculate_average() for student in self.students) # find highest average grade
        for student in self.students:
            if student.calculate_average() == top_grade:
                top_students.append(student)
        return top_students

# %% [markdown]
# #### Test Program

# %%
import pandas as pd
import numpy as np

num_students = 100

names = [f"Student {i+1}" for i in range(num_students)]

# Create random ages from 15 to 19
ages = np.random.randint(15, 19, size=num_students)

# Create random grades from 0 to 100
maths_grades = np.random.uniform(0, 100, size=num_students)
physics_grades = np.random.uniform(0, 100, size=num_students)
chemistry_grades = np.random.uniform(0, 100, size=num_students)

# Create DataFrame
students_df = pd.DataFrame({
    'Name': names,
    'Age': ages,
    'Maths': maths_grades,
    "Physics": physics_grades,
    "Chemistry": chemistry_grades

})
students_df.head()
# Out:
#         Name  Age      Maths    Physics  Chemistry
# 0  Student 1   18  71.621381  71.348927  87.297439
# 1  Student 2   16  34.046841  51.207126  10.238857
# 2  Student 3   18  80.202804  28.568654  36.360742
# 3  Student 4   15  67.246504  27.358048  42.633140
# 4  Student 5   15   7.011118  27.735766  96.170166

# %%
# Create school object
hcmus_uni = School()

# Create student object and add them to shool
for st in students_df.itertuples(index=False):
    student = Student(name = st.Name, age = st.Age)
    student.add_grade(st.Maths)
    student.add_grade(st.Physics)
    student.add_grade(st.Chemistry)
    hcmus_uni.add_student(student)
# Out:
# Added grade 71.6213811842523 to Student 1's grade list.
# Added grade 71.34892691002047 to Student 1's grade list.
# Added grade 87.29743946108958 to Student 1's grade list.
# Added Student 1 to the student list.
# Added grade 34.04684126836255 to Student 2's grade list.
# Added grade 51.20712622321657 to Student 2's grade list.
# Added grade 10.23885651743356 to Student 2's grade list.
# Added Student 2 to the student list.
# Added grade 80.20280420330486 to Student 3's grade list.
# Added grade 28.568653646590015 to Student 3's grade list.
# Added grade 36.36074154166534 to Student 3's grade list.
# Added Student 3 to the student list.
# Added grade 67.24650360839551 to Student 4's grade list.
# Added grade 27.358048302925376 to Student 4's grade list.
# Added grade 42.633140159194106 to Student 4's grade list.
# Added Student 4 to the student list.
# Added grade 7.011117999324201 to Student 5's grade list.
# Added grade 27.735766187182676 to Student 5's grade list.
# Added grade 96.17016637583006 to Student 5's grade list.
# Added Student 5 to the student list.
# Added grade 16.632613542435358 to Student 6's grade list.
# Added grade 90.82847213795216 to Student 6's grade list.
# Added grade 47.621402331656014 to Student 6's grade list.
# Added Student 6 to the student list.
# Added grade 78.07132446028305 to Student 7's grade list.
# Added grade 34.38573795442748 to Student 7's grade list.
# Added grade 37.334276907814136 to Student 7's grade list.
# Added Student 7 to the student list.
# Added grade 86.67416143125706 to Student 8's grade list.
# Added grade 72.74809942537853 to Student 8's grade list.
# Added grade 93.77893200569557 to Student 8's grade list.
# Added Student 8 to the student list.
# Added grade 30.40416162268007 to Student 9's grade list.
# Added grade 89.12878865053597 to Student 9's grade list.
# Added grade 75.89875939459826 to Student 9's grade list.
# Added Student 9 to the student list.
# Added grade 71.47645289402578 to Student 10's grade list.
# Added grade 8.318280354006557 to Student 10's grade list.
# Added grade 58.098623499242365 to Student 10's grade list.
# Added Student 10 to the student list.
# Added grade 41.5311420024172 to Student 11's grade list.
# Added grade 92.92762002100461 to Student 11's grade list.
# Added grade 58.38401907440118 to Student 11's grade list.
# Added Student 11 to the student list.
# Added grade 44.576433341150526 to Student 12's grade list.
# Added grade 94.96031127550063 to Student 12's grade list.
# Added grade 46.06305726510496 to Student 12's grade list.
# Added Student 12 to the student list.
# Added grade 29.68334082148838 to Student 13's grade list.
# Added grade 73.02041613411828 to Student 13's grade list.
# Added grade 5.879919540054601 to Student 13's grade list.
# Added Student 13 to the student list.
# Added grade 31.209206072871677 to Student 14's grade list.
# Added grade 31.23179399991498 to Student 14's grade list.
# Added grade 13.412847214753477 to Student 14's grade list.
# Added Student 14 to the student list.
# Added grade 25.39317911352359 to Student 15's grade list.
# Added grade 72.92348962144168 to Student 15's grade list.
# Added grade 89.90251128154654 to Student 15's grade list.
# Added Student 15 to the student list.
# Added grade 23.21640705575019 to Student 16's grade list.
# Added grade 38.32594354201585 to Student 16's grade list.
# Added grade 93.53325215784886 to Student 16's grade list.
# Added Student 16 to the student list.
# Added grade 54.87918807156884 to Student 17's grade list.
# Added grade 83.72599316467503 to Student 17's grade list.
# Added grade 92.3072143752275 to Student 17's grade list.
# Added Student 17 to the student list.
# Added grade 70.87264065262569 to Student 18's grade list.
# Added grade 34.0021540733185 to Student 18's grade list.
# Added grade 80.999679751717 to Student 18's grade list.
# Added Student 18 to the student list.
# Added grade 49.56209660550115 to Student 19's grade list.
# Added grade 85.01127445757294 to Student 19's grade list.
# Added grade 33.19127469953248 to Student 19's grade list.
# Added Student 19 to the student list.
# Added grade 41.26711255940698 to Student 20's grade list.
# Added grade 97.34210453758556 to Student 20's grade list.
# Added grade 16.95356091347312 to Student 20's grade list.
# Added Student 20 to the student list.
# Added grade 83.73764182895886 to Student 21's grade list.
# Added grade 60.17042209924933 to Student 21's grade list.
# Added grade 20.62770532103465 to Student 21's grade list.
# Added Student 21 to the student list.
# Added grade 32.26134941118799 to Student 22's grade list.
# Added grade 84.61883877625645 to Student 22's grade list.
# Added grade 21.47078839637402 to Student 22's grade list.
# Added Student 22 to the student list.
# Added grade 49.791177050200844 to Student 23's grade list.
# Added grade 60.00546699427288 to Student 23's grade list.
# Added grade 89.5107942061396 to Student 23's grade list.
# Added Student 23 to the student list.
# Added grade 19.480462231061257 to Student 24's grade list.
# Added grade 96.14233519934304 to Student 24's grade list.
# Added grade 64.58436765989904 to Student 24's grade list.
# Added Student 24 to the student list.
# Added grade 43.58752887124796 to Student 25's grade list.
# Added grade 38.66569557605789 to Student 25's grade list.
# Added grade 59.34460702936325 to Student 25's grade list.
# Added Student 25 to the student list.
# Added grade 84.54459445161933 to Student 26's grade list.
# Added grade 92.4014540973389 to Student 26's grade list.
# Added grade 8.217987501225233 to Student 26's grade list.
# Added Student 26 to the student list.
# Added grade 95.03087205026793 to Student 27's grade list.
# Added grade 50.29237282196165 to Student 27's grade list.
# Added grade 17.00494784000084 to Student 27's grade list.
# Added Student 27 to the student list.
# Added grade 42.05772039086034 to Student 28's grade list.
# Added grade 15.569363747504283 to Student 28's grade list.
# Added grade 31.774605643468632 to Student 28's grade list.
# Added Student 28 to the student list.
# Added grade 92.59680612135261 to Student 29's grade list.
# Added grade 86.90755074436129 to Student 29's grade list.
# Added grade 34.650053087407464 to Student 29's grade list.
# Added Student 29 to the student list.
# Added grade 69.64470694959338 to Student 30's grade list.
# Added grade 5.462340093077933 to Student 30's grade list.
# Added grade 37.951272648187796 to Student 30's grade list.
# Added Student 30 to the student list.
# Added grade 25.638487477528894 to Student 31's grade list.
# Added grade 4.695480857944689 to Student 31's grade list.
# Added grade 21.842173309458467 to Student 31's grade list.
# Added Student 31 to the student list.
# Added grade 57.998563774356214 to Student 32's grade list.
# Added grade 23.28657027414223 to Student 32's grade list.
# Added grade 63.736273997553916 to Student 32's grade list.
# Added Student 32 to the student list.
# Added grade 69.71594828881994 to Student 33's grade list.
# Added grade 7.02458696271937 to Student 33's grade list.
# Added grade 31.399715064250334 to Student 33's grade list.
# Added Student 33 to the student list.
# Added grade 91.64220163941359 to Student 34's grade list.
# Added grade 2.5852144404773014 to Student 34's grade list.
# Added grade 15.987673112789713 to Student 34's grade list.
# Added Student 34 to the student list.
# Added grade 59.71119141342941 to Student 35's grade list.
# Added grade 22.87860012033961 to Student 35's grade list.
# Added grade 64.78547420730936 to Student 35's grade list.
# Added Student 35 to the student list.
# Added grade 17.76262887221931 to Student 36's grade list.
# Added grade 47.220266074575036 to Student 36's grade list.
# Added grade 44.50749815232232 to Student 36's grade list.
# Added Student 36 to the student list.
# Added grade 83.36058506854927 to Student 37's grade list.
# Added grade 86.93846721891279 to Student 37's grade list.
# Added grade 72.94779723708467 to Student 37's grade list.
# Added Student 37 to the student list.
# Added grade 87.46180409720976 to Student 38's grade list.
# Added grade 78.95116759269938 to Student 38's grade list.
# Added grade 22.6980070826469 to Student 38's grade list.
# Added Student 38 to the student list.
# Added grade 12.518680420471329 to Student 39's grade list.
# Added grade 63.414096530929164 to Student 39's grade list.
# Added grade 26.176552362045857 to Student 39's grade list.
# Added Student 39 to the student list.
# Added grade 27.291328819938798 to Student 40's grade list.
# Added grade 9.729169055731134 to Student 40's grade list.
# Added grade 41.8263950788334 to Student 40's grade list.
# Added Student 40 to the student list.
# Added grade 95.41512379724955 to Student 41's grade list.
# Added grade 95.54747156868714 to Student 41's grade list.
# Added grade 74.40659303424418 to Student 41's grade list.
# Added Student 41 to the student list.
# Added grade 16.74669350118182 to Student 42's grade list.
# Added grade 41.23494200419927 to Student 42's grade list.
# Added grade 53.48923428912331 to Student 42's grade list.
# Added Student 42 to the student list.
# Added grade 57.13793722072585 to Student 43's grade list.
# Added grade 82.86835215256346 to Student 43's grade list.
# Added grade 91.96956011328035 to Student 43's grade list.
# Added Student 43 to the student list.
# Added grade 62.034658873508974 to Student 44's grade list.
# Added grade 67.49322863429592 to Student 44's grade list.
# Added grade 0.19377743461501673 to Student 44's grade list.
# Added Student 44 to the student list.
# Added grade 7.48182453603361 to Student 45's grade list.
# Added grade 42.44129689729307 to Student 45's grade list.
# Added grade 91.34826359831453 to Student 45's grade list.
# Added Student 45 to the student list.
# Added grade 74.00719587650954 to Student 46's grade list.
# Added grade 10.72927280723105 to Student 46's grade list.
# Added grade 22.45947030443617 to Student 46's grade list.
# Added Student 46 to the student list.
# Added grade 31.029226217675387 to Student 47's grade list.
# Added grade 48.28210134297778 to Student 47's grade list.
# Added grade 54.34412491710524 to Student 47's grade list.
# Added Student 47 to the student list.
# Added grade 6.73251374005085 to Student 48's grade list.
# Added grade 30.32208934938394 to Student 48's grade list.
# Added grade 16.374844176582037 to Student 48's grade list.
# Added Student 48 to the student list.
# Added grade 81.45753359266716 to Student 49's grade list.
# Added grade 27.70743337028564 to Student 49's grade list.
# Added grade 71.69499607368037 to Student 49's grade list.
# Added Student 49 to the student list.
# Added grade 4.579887441141095 to Student 50's grade list.
# Added grade 76.57490771688565 to Student 50's grade list.
# Added grade 67.94285677149328 to Student 50's grade list.
# Added Student 50 to the student list.
# Added grade 17.284718196768743 to Student 51's grade list.
# Added grade 28.605660393261033 to Student 51's grade list.
# Added grade 24.67330229583482 to Student 51's grade list.
# Added Student 51 to the student list.
# Added grade 32.71293192000924 to Student 52's grade list.
# Added grade 65.08263978878517 to Student 52's grade list.
# Added grade 72.77080841160338 to Student 52's grade list.
# Added Student 52 to the student list.
# Added grade 84.82069369268623 to Student 53's grade list.
# Added grade 9.25239979082101 to Student 53's grade list.
# Added grade 69.9831144339478 to Student 53's grade list.
# Added Student 53 to the student list.
# Added grade 16.636862191599832 to Student 54's grade list.
# Added grade 77.4353003551757 to Student 54's grade list.
# Added grade 19.653848052133604 to Student 54's grade list.
# Added Student 54 to the student list.
# Added grade 40.710527708337764 to Student 55's grade list.
# Added grade 20.443141716511192 to Student 55's grade list.
# Added grade 53.38072227047205 to Student 55's grade list.
# Added Student 55 to the student list.
# Added grade 28.958433375878943 to Student 56's grade list.
# Added grade 38.28778296898899 to Student 56's grade list.
# Added grade 84.41420233571097 to Student 56's grade list.
# Added Student 56 to the student list.
# Added grade 57.780225340348466 to Student 57's grade list.
# Added grade 9.460221584650863 to Student 57's grade list.
# Added grade 39.34297770100801 to Student 57's grade list.
# Added Student 57 to the student list.
# Added grade 47.290946344816774 to Student 58's grade list.
# Added grade 35.716801161641484 to Student 58's grade list.
# Added grade 78.70041219901887 to Student 58's grade list.
# Added Student 58 to the student list.
# Added grade 30.52445897376076 to Student 59's grade list.
# Added grade 55.7888192734615 to Student 59's grade list.
# Added grade 48.61153205881804 to Student 59's grade list.
# Added Student 59 to the student list.
# Added grade 85.74985457701464 to Student 60's grade list.
# Added grade 55.505908699753384 to Student 60's grade list.
# Added grade 50.60078966118999 to Student 60's grade list.
# Added Student 60 to the student list.
# Added grade 72.98619629925685 to Student 61's grade list.
# Added grade 53.53521333709461 to Student 61's grade list.
# Added grade 61.72662736369558 to Student 61's grade list.
# Added Student 61 to the student list.
# Added grade 49.05903296120137 to Student 62's grade list.
# Added grade 52.236730666859835 to Student 62's grade list.
# Added grade 82.95608693811513 to Student 62's grade list.
# Added Student 62 to the student list.
# Added grade 34.19363873350427 to Student 63's grade list.
# Added grade 63.861174449345214 to Student 63's grade list.
# Added grade 57.26315491183014 to Student 63's grade list.
# Added Student 63 to the student list.
# Added grade 29.39258614893916 to Student 64's grade list.
# Added grade 64.6657537400881 to Student 64's grade list.
# Added grade 28.37130032804678 to Student 64's grade list.
# Added Student 64 to the student list.
# Added grade 12.620220209161614 to Student 65's grade list.
# Added grade 14.748170145631445 to Student 65's grade list.
# Added grade 88.2020075596947 to Student 65's grade list.
# Added Student 65 to the student list.
# Added grade 33.63603049799778 to Student 66's grade list.
# Added grade 7.15064315519186 to Student 66's grade list.
# Added grade 56.328677552431195 to Student 66's grade list.
# Added Student 66 to the student list.
# Added grade 26.943333372205036 to Student 67's grade list.
# Added grade 70.73497629453291 to Student 67's grade list.
# Added grade 75.96153912211008 to Student 67's grade list.
# Added Student 67 to the student list.
# Added grade 23.794845685099187 to Student 68's grade list.
# Added grade 7.533354074913346 to Student 68's grade list.
# Added grade 44.72811976054357 to Student 68's grade list.
# Added Student 68 to the student list.
# Added grade 66.33474463800437 to Student 69's grade list.
# Added grade 76.23482840301325 to Student 69's grade list.
# Added grade 67.66456320409078 to Student 69's grade list.
# Added Student 69 to the student list.
# Added grade 15.914713743867138 to Student 70's grade list.
# Added grade 86.79015801668605 to Student 70's grade list.
# Added grade 73.56974593099865 to Student 70's grade list.
# Added Student 70 to the student list.
# Added grade 22.411190492339085 to Student 71's grade list.
# Added grade 84.9738251421621 to Student 71's grade list.
# Added grade 47.19394198069645 to Student 71's grade list.
# Added Student 71 to the student list.
# Added grade 31.386594974991787 to Student 72's grade list.
# Added grade 47.334836991911764 to Student 72's grade list.
# Added grade 93.7293293024734 to Student 72's grade list.
# Added Student 72 to the student list.
# Added grade 70.7696226455043 to Student 73's grade list.
# Added grade 68.60649428111046 to Student 73's grade list.
# Added grade 53.87757532082453 to Student 73's grade list.
# Added Student 73 to the student list.
# Added grade 65.39488963550927 to Student 74's grade list.
# Added grade 90.78847335093091 to Student 74's grade list.
# Added grade 21.132542113219756 to Student 74's grade list.
# Added Student 74 to the student list.
# Added grade 43.425519859510956 to Student 75's grade list.
# Added grade 87.05450424708744 to Student 75's grade list.
# Added grade 81.0203752838875 to Student 75's grade list.
# Added Student 75 to the student list.
# Added grade 22.788859225222925 to Student 76's grade list.
# Added grade 29.78952799750597 to Student 76's grade list.
# Added grade 9.872185125374532 to Student 76's grade list.
# Added Student 76 to the student list.
# Added grade 6.784696605280671 to Student 77's grade list.
# Added grade 74.23942922850169 to Student 77's grade list.
# Added grade 48.0940532157547 to Student 77's grade list.
# Added Student 77 to the student list.
# Added grade 46.55092164315887 to Student 78's grade list.
# Added grade 87.67995564896628 to Student 78's grade list.
# Added grade 18.815031787343294 to Student 78's grade list.
# Added Student 78 to the student list.
# Added grade 62.6339216499525 to Student 79's grade list.
# Added grade 18.876112341477626 to Student 79's grade list.
# Added grade 33.89161311006901 to Student 79's grade list.
# Added Student 79 to the student list.
# Added grade 93.75642198890758 to Student 80's grade list.
# Added grade 15.18204294776142 to Student 80's grade list.
# Added grade 44.6449829474989 to Student 80's grade list.
# Added Student 80 to the student list.
# Added grade 30.394555373010945 to Student 81's grade list.
# Added grade 68.11116996428385 to Student 81's grade list.
# Added grade 43.64574911035973 to Student 81's grade list.
# Added Student 81 to the student list.
# Added grade 76.66742167225902 to Student 82's grade list.
# Added grade 95.01625719548228 to Student 82's grade list.
# Added grade 29.4354709190899 to Student 82's grade list.
# Added Student 82 to the student list.
# Added grade 13.003589818014449 to Student 83's grade list.
# Added grade 52.53239091836349 to Student 83's grade list.
# Added grade 81.56248014335749 to Student 83's grade list.
# Added Student 83 to the student list.
# Added grade 34.86924031588108 to Student 84's grade list.
# Added grade 76.57074020281563 to Student 84's grade list.
# Added grade 96.0254824508581 to Student 84's grade list.
# Added Student 84 to the student list.
# Added grade 70.45499254276302 to Student 85's grade list.
# Added grade 41.69611259259154 to Student 85's grade list.
# Added grade 73.09152301765913 to Student 85's grade list.
# Added Student 85 to the student list.
# Added grade 82.58464791346401 to Student 86's grade list.
# Added grade 76.93712487393853 to Student 86's grade list.
# Added grade 68.41271958828537 to Student 86's grade list.
# Added Student 86 to the student list.
# Added grade 38.820502196682504 to Student 87's grade list.
# Added grade 62.20987018846434 to Student 87's grade list.
# Added grade 76.32320754127578 to Student 87's grade list.
# Added Student 87 to the student list.
# Added grade 28.460462493490056 to Student 88's grade list.
# Added grade 39.14633068988722 to Student 88's grade list.
# Added grade 10.10916681447831 to Student 88's grade list.
# Added Student 88 to the student list.
# Added grade 93.8997044250643 to Student 89's grade list.
# Added grade 56.03755428230072 to Student 89's grade list.
# Added grade 38.73071067787991 to Student 89's grade list.
# Added Student 89 to the student list.
# Added grade 49.36777529959482 to Student 90's grade list.
# Added grade 42.35705163207748 to Student 90's grade list.
# Added grade 21.59463331059175 to Student 90's grade list.
# Added Student 90 to the student list.
# Added grade 46.92609123014812 to Student 91's grade list.
# Added grade 68.9340701513547 to Student 91's grade list.
# Added grade 12.736890207266926 to Student 91's grade list.
# Added Student 91 to the student list.
# Added grade 73.75816591226811 to Student 92's grade list.
# Added grade 74.56603041343583 to Student 92's grade list.
# Added grade 87.48409891522721 to Student 92's grade list.
# Added Student 92 to the student list.
# Added grade 85.37461475327116 to Student 93's grade list.
# Added grade 72.12646539420705 to Student 93's grade list.
# Added grade 47.45956175271746 to Student 93's grade list.
# Added Student 93 to the student list.
# Added grade 44.34932923047129 to Student 94's grade list.
# Added grade 90.54409180810038 to Student 94's grade list.
# Added grade 77.21716143352633 to Student 94's grade list.
# Added Student 94 to the student list.
# Added grade 74.13061213006048 to Student 95's grade list.
# Added grade 81.83281440193605 to Student 95's grade list.
# Added grade 67.28417016228434 to Student 95's grade list.
# Added Student 95 to the student list.
# Added grade 87.62869555739172 to Student 96's grade list.
# Added grade 33.63419824886129 to Student 96's grade list.
# Added grade 46.13005666156308 to Student 96's grade list.
# Added Student 96 to the student list.
# Added grade 96.33892133658108 to Student 97's grade list.
# Added grade 66.27027623232267 to Student 97's grade list.
# Added grade 0.18251206092350092 to Student 97's grade list.
# Added Student 97 to the student list.
# Added grade 56.88003794558006 to Student 98's grade list.
# Added grade 99.46565752118327 to Student 98's grade list.
# Added grade 50.83709573011581 to Student 98's grade list.
# Added Student 98 to the student list.
# Added grade 82.27143070457586 to Student 99's grade list.
# Added grade 79.91430200637865 to Student 99's grade list.
# Added grade 41.29599210485046 to Student 99's grade list.
# Added Student 99 to the student list.
# Added grade 4.899850834643294 to Student 100's grade list.
# Added grade 52.21423966353317 to Student 100's grade list.
# Added grade 40.85765860783223 to Student 100's grade list.
# Added Student 100 to the student list.

# %%
# Test another methods
hcmus_uni.find_student("Student 12")

top_students = hcmus_uni.get_top_student()
print("Top students:")
for student in top_students:
    student.describe()

hcmus_uni.remove_student("Student 99")
hcmus_uni.find_student("Student 99")
# Out:
# Name: Student 12
# Age: 15
# Grade: [44.576433341150526, 94.96031127550063, 46.06305726510496]
# Average Grade: 61.86660062725204
#
# Top students:
# Name: Student 41
# Age: 17
# Grade: [95.41512379724955, 95.54747156868714, 74.40659303424418]
# Average Grade: 88.45639613339362
#
# Removed Student 99 from the student list.
# Student 99 not found in the student list!
